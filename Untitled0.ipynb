# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVASHANKARI04/Supermarket-Sales-Reports/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/supermarket_sales new.csv")

# %%
df
# Out:
#      Gender   Invoice ID Branch       City Customer type  \
# 0    Female  750-67-8428      A     Yangon        Member
# 1    Female  226-31-3081      C  Naypyitaw        Normal
# 2    Female  355-53-5943      A     Yangon        Member
# 3    Female  315-22-5665      C  Naypyitaw        Normal
# 4    Female  665-32-9167      A     Yangon        Member
# ..      ...          ...    ...        ...           ...
# 995    Male  745-74-0715      A     Yangon        Normal
# 996    Male  690-01-6631      B   Mandalay        Normal
# 997    Male  233-67-5758      C  Naypyitaw        Normal
# 998    Male  727-02-1313      A     Yangon        Member
# 999    Male  347-56-2442      A     Yangon        Normal
#
#                Product line  Unit price  Quantity    Tax 5%
# 0         Health and beauty       74.69         7  261.4150
# 1    Electronic accessories       15.28         5    3.8200
# 2    Electronic accessories       68.84         6   20.6520
# ...

# %%
df.set_index("Invoice ID",inplace=True)

# %%
df
# Out:
#              Gender Branch       City Customer type            Product line  \
# Invoice ID
# 750-67-8428  Female      A     Yangon        Member       Health and beauty
# 226-31-3081  Female      C  Naypyitaw        Normal  Electronic accessories
# 355-53-5943  Female      A     Yangon        Member  Electronic accessories
# 315-22-5665  Female      C  Naypyitaw        Normal      Home and lifestyle
# 665-32-9167  Female      A     Yangon        Member       Health and beauty
# ...             ...    ...        ...           ...                     ...
# 745-74-0715    Male      A     Yangon        Normal  Electronic accessories
# 690-01-6631    Male      B   Mandalay        Normal     Fashion accessories
# 233-67-5758    Male      C  Naypyitaw        Normal       Health and beauty
# 727-02-1313    Male      A     Yangon        Member      Food and beverages
# 347-56-2442    Male      A     Yangon        Normal      Home and lifestyle
#
#              Unit price  Quantity    Tax 5%
# ...

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
px.scatter(df,x="Gender",y="City",color="Branch",size="Quantity")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,x="Gender",y="Product line",color="Branch",size="Quantity")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter_3d(df,x="Gender",y="Product line",z="Unit price",color="Branch",size="Quantity")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x="Unit price",nbins=10,color="Branch")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x="Unit price",nbins=10,color="Branch",barmode="group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x="Unit price",nbins=10,color="Gender",barmode="group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data=px.pie(df,names="Product line",values="Quantity")

# %%
data
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.update_traces(textposition="inside",textinfo="percent+label")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.sunburst(df,path=["Gender","Unit price","Quantity"],values="Tax 5%")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.sunburst(df,path=["Gender","Product line","Tax 5%","Quantity","City"],values="Unit price")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
